# %%
num = float(input("Enter a decimal number: "))
integer = int(num)
string = str(num)
print(f"Original float: {num}")
print(f"Converted to integer: {integer}")
print(f'Converted to string: "{string}"')
# Out:
# Original float: 12.25
# Converted to integer: 12
# Converted to string: "12.25"

# %%
full_name = input("Enter your full name: ")
first_name, last_name = full_name.split()
initial = first_name[0].upper() + "." + last_name[0].upper()
print("Your initials are:", initial)
# Out:
# Your initials are: P.H

# %%
word = input("Enter a word: ")
index = int(input("Enter starting index: "))
substring = word[index:]
print(f'Substring from index {index}: "{substring}"')
# Out:
# Substring from index 3: "tyush"

# %%
password = input("Enter your password: ")

has_letter = any(c.isalpha() for c in password)
has_number = any(c.isdigit() for c in password)
has_special = any(c in "@#$%&" for c in password)

if len(password) < 6 or (has_letter and not has_number and not has_special):
    print("Password strength: Weak")
elif len(password) >= 6 and has_letter and has_number and not has_special:
    print("Password strength: Moderate")
elif len(password) >= 8 and has_letter and has_number and has_special:
    print("Password strength: Strong")
else:
    print("Password strength: Weak")
# Out:
# Password strength: Moderate

# %%
text = input("Enter a string: ").lower()
frequency = {}
for char in text:
    if char.isalpha():
        frequency[char] = frequency.get(char, 0) + 1
for char, count in frequency.items():
    print(f"{char} → {count}")
# Out:
# b → 1
# a → 3
# n → 2

# %%
text = input("Enter a string: ").lower()
vowels = "aeiou"
vowel_count = 0
consonant_count = 0
for char in text:
    if char.isalpha():
        if char in vowels:
            vowel_count += 1
        else:
            consonant_count += 1
print("Vowels:", vowel_count)
print("Consonants:", consonant_count)
# Out:
# Vowels: 3
# Consonants: 7
